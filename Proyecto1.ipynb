# %%
# !pip install voila
# Out:
# Requirement already satisfied: voila in c:\users\user\downloads\mi_entorno\lib\site-packages (0.5.8)
# Requirement already satisfied: jupyter-client<9,>=7.4.4 in c:\users\user\downloads\mi_entorno\lib\site-packages (from voila) (8.6.3)
# Requirement already satisfied: jupyter-core>=4.11.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from voila) (5.7.2)
# Requirement already satisfied: jupyter-server<3,>=1.18 in c:\users\user\downloads\mi_entorno\lib\site-packages (from voila) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.3.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from voila) (2.27.3)
# Requirement already satisfied: nbclient>=0.4.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from voila) (0.10.2)
# Requirement already satisfied: nbconvert<8,>=6.4.5 in c:\users\user\downloads\mi_entorno\lib\site-packages (from voila) (7.16.6)
# Requirement already satisfied: traitlets<6,>=5.0.3 in c:\users\user\downloads\mi_entorno\lib\site-packages (from voila) (5.14.3)
# Requirement already satisfied: websockets>=9.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from voila) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-client<9,>=7.4.4->voila) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-client<9,>=7.4.4->voila) (26.3.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-client<9,>=7.4.4->voila) (6.4.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-core>=4.11.0->voila) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-core>=4.11.0->voila) (310)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-server<3,>=1.18->voila) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-server<3,>=1.18->voila) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-server<3,>=1.18->voila) (3.1.6)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-server<3,>=1.18->voila) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-server<3,>=1.18->voila) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-server<3,>=1.18->voila) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-server<3,>=1.18->voila) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-server<3,>=1.18->voila) (24.2)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-server<3,>=1.18->voila) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-server<3,>=1.18->voila) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-server<3,>=1.18->voila) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-server<3,>=1.18->voila) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-server<3,>=1.18->voila) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\downloads\mi_entorno\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\user\downloads\mi_entorno\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\user\downloads\mi_entorno\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\user\downloads\mi_entorno\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (3.1.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (2.19.1)
# Requirement already satisfied: idna>=2.8 in c:\users\user\downloads\mi_entorno\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.18->voila) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.18->voila) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\user\downloads\mi_entorno\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=1.18->voila) (21.2.0)
# Requirement already satisfied: webencodings in c:\users\user\downloads\mi_entorno\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (0.24.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (0.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\user\downloads\mi_entorno\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=1.18->voila) (2.21.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\downloads\mi_entorno\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client<9,>=7.4.4->voila) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\downloads\mi_entorno\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\downloads\mi_entorno\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\downloads\mi_entorno\lib\site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (4.13.0)
# Requirement already satisfied: fqdn in c:\users\user\downloads\mi_entorno\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\user\downloads\mi_entorno\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\user\downloads\mi_entorno\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=1.18->voila) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\user\downloads\mi_entorno\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=1.18->voila) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\user\downloads\mi_entorno\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (2.9.0.20241206)

# %%
# !pip install tensorflow keras numpy matplotlib ipywidgets pillow
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow (from versions: none)
# ERROR: No matching distribution found for tensorflow

# %%
# !python --version
# Out:
# Python 3.13.2

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\user\downloads\mi_entorno\lib\site-packages (25.0.1)

# %%
# !pip install keras numpy matplotlib ipywidgets pillow
# Out:
# Requirement already satisfied: keras in c:\users\user\downloads\mi_entorno\lib\site-packages (3.9.1)
# Requirement already satisfied: numpy in c:\users\user\downloads\mi_entorno\lib\site-packages (2.2.4)
# Requirement already satisfied: matplotlib in c:\users\user\downloads\mi_entorno\lib\site-packages (3.10.1)
# Requirement already satisfied: ipywidgets in c:\users\user\downloads\mi_entorno\lib\site-packages (8.1.5)
# Requirement already satisfied: pillow in c:\users\user\downloads\mi_entorno\lib\site-packages (11.1.0)
# Requirement already satisfied: absl-py in c:\users\user\downloads\mi_entorno\lib\site-packages (from keras) (2.2.1)
# Requirement already satisfied: rich in c:\users\user\downloads\mi_entorno\lib\site-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in c:\users\user\downloads\mi_entorno\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\user\downloads\mi_entorno\lib\site-packages (from keras) (3.13.0)
# Requirement already satisfied: optree in c:\users\user\downloads\mi_entorno\lib\site-packages (from keras) (0.14.1)
# Requirement already satisfied: ml-dtypes in c:\users\user\downloads\mi_entorno\lib\site-packages (from keras) (0.5.1)
# Requirement already satisfied: packaging in c:\users\user\downloads\mi_entorno\lib\site-packages (from keras) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\downloads\mi_entorno\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\downloads\mi_entorno\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ipywidgets) (9.0.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: colorama in c:\users\user\downloads\mi_entorno\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\user\downloads\mi_entorno\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\user\downloads\mi_entorno\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\user\downloads\mi_entorno\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\user\downloads\mi_entorno\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\downloads\mi_entorno\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from optree->keras) (4.13.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: wcwidth in c:\users\user\downloads\mi_entorno\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\user\downloads\mi_entorno\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.preprocessing import StandardScaler


carpeta = "dataset/imagenes"  
nombre_imagen = "carroproyecto1.jpg"
ruta_imagen = os.path.join(carpeta, nombre_imagen).replace("\\", "/")  # Corregir la barra invertida

def cargar_imagen(ruta):
    try:
        img = Image.open(ruta)
        img = img.resize((224, 224))  
        plt.imshow(img)
        plt.axis('off')
        plt.show()
    except Exception as e:
        print(f"Error al cargar la imagen {ruta}: {e}")

def procesar_imagen(ruta):
    try:
        img = Image.open(ruta).convert('RGB')
        img = img.resize((224, 224))  
        img_array = np.array(img) / 255.0  # Normalización
        img_array = img_array.reshape(1, -1)  
        scaler = StandardScaler()
        img_array = scaler.fit_transform(img_array)  
        return img_array
    except Exception as e:
        print(f"Error al procesar la imagen {ruta}: {e}")
        return None


if os.path.exists(ruta_imagen):  
    print(f"✅ Imagen encontrada en: {ruta_imagen}")
    cargar_imagen(ruta_imagen)
    imagen_procesada = procesar_imagen(ruta_imagen)
    if imagen_procesada is not None:
        print("Imagen procesada correctamente:", imagen_procesada.shape)
else:
    print(f"❌ No se encontró la imagen en la ruta especificada: {ruta_imagen}")

    # Mostrar los archivos en la carpeta para depuración
    if os.path.exists(carpeta):
        print(f"📂 Contenido de {carpeta}: {os.listdir(carpeta)}")
    else:
        print(f"⚠️ La carpeta {carpeta} no existe.")
# Out:
# ❌ No se encontró la imagen en la ruta especificada: dataset/imagenes/carroproyecto1.jpg
# 📂 Contenido de dataset/imagenes: ['.ipynb_checkpoints', 'carroproyecto1.jgp', 'carroproyecto22.jgp', 'gatoproyecto.jgp', 'gatoproyecto1.jgp', 'perroproyecto.jpg', 'perroproyecto1.jpg']

# %%
import os


os.makedirs("dataset/gatos", exist_ok=True)
os.makedirs("dataset/perros", exist_ok=True)
os.makedirs("dataset/carros", exist_ok=True)

print("Carpetas creadas correctamente.")
# Out:
# Carpetas creadas correctamente.

# %%
import os
from PIL import Image
import numpy as np

def cargar_imagenes(ruta):
    imagenes = []
    for archivo in os.listdir(ruta):
        ruta_completa = os.path.join(ruta, archivo)

        # Omitir directorios como .ipynb_checkpoints
        if not os.path.isfile(ruta_completa):  
            continue

        try:
            img = Image.open(ruta_completa).resize((224, 224))
            imagenes.append(np.array(img))
        except Exception as e:
            print(f"Error con la imagen {ruta_completa}: {e}")

    return np.array(imagenes)

ruta_gatos = "dataset/gatos"
ruta_perros = "dataset/perros"

imagenes_gatos = cargar_imagenes(ruta_gatos)
imagenes_perros = cargar_imagenes(ruta_perros)

print("Imágenes cargadas y preprocesadas correctamente.")
# Out:
# Imágenes cargadas y preprocesadas correctamente.

# %%
import numpy as np
import os
import cv2
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline


ruta_imagenes = r'C:\Users\USER\Downloads\proyecto\dataset'

def cargar_imagenes(ruta_imagenes):
    imagenes = []
    etiquetas = []
    for etiqueta in os.listdir(ruta_imagenes):
        carpeta = os.path.join(ruta_imagenes, etiqueta)
        if os.path.isdir(carpeta):
            for archivo in os.listdir(carpeta):
                if archivo.endswith(('.jpg', '.png')):
                    img = cv2.imread(os.path.join(carpeta, archivo))
                    if img is not None:
                        img = cv2.resize(img, (64, 64))
                        imagenes.append(img.flatten())
                        etiquetas.append(etiqueta)
                    else:
                        print(f"Error al cargar la imagen: {archivo}")
    return np.array(imagenes), np.array(etiquetas)


X, y = cargar_imagenes(ruta_imagenes)


num_clases = len(np.unique(y))
if num_clases < 2:
    raise ValueError("Se necesitan al menos dos clases para entrenar el modelo.")


test_size = max(1, num_clases)  


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=test_size, stratify=y, random_state=42)


n_splits = min(5, np.min(np.unique(y, return_counts=True)[1]))  # No mayor que la clase con menos datos
skf = StratifiedKFold(n_splits=n_splits)


modelo = make_pipeline(PCA(n_components=min(6, X_train.shape[1])), SVC(kernel="linear"))

# Entrenar el modelo
modelo.fit(X_train, y_train)


scores = cross_val_score(modelo, X_scaled, y, cv=skf)
print(f"Precisión media de la validación cruzada: {scores.mean() * 100:.2f}%")
print(f"Desviación estándar de la precisión: {scores.std() * 100:.2f}%")


precision = modelo.score(X_test, y_test)
print(f"Precisión en el conjunto de prueba: {precision * 100:.2f}%")
# Out:
# Precisión media de la validación cruzada: 38.89%
# Desviación estándar de la precisión: 5.56%
# Precisión en el conjunto de prueba: 20.00%

# %%
import os

ruta_gatos = "dataset/gatos"
ruta_perros = "dataset/perros"

print("Número de imágenes en la carpeta de gatos:", len(os.listdir(ruta_gatos)))
print("Número de imágenes en la carpeta de perros:", len(os.listdir(ruta_perros)))

# %%
import os

ruta_gatos = "dataset/gatos"
ruta_perros = "dataset/perros"

# Filtrar solo archivos de imagen (ignorando .ipynb_checkpoints y otros archivos no válidos)
imagenes_gatos = [f for f in os.listdir(ruta_gatos) if f.endswith((".jpg", ".png", ".jpeg"))]
imagenes_perros = [f for f in os.listdir(ruta_perros) if f.endswith((".jpg", ".png", ".jpeg"))]

print("Número de imágenes en la carpeta de gatos:", len(imagenes_gatos))
print("Número de imágenes en la carpeta de perros:", len(imagenes_perros))

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os


def obtener_imagen_valida(ruta_carpeta):
    for archivo in os.listdir(ruta_carpeta):
        if archivo.lower().endswith((".png", ".jpg", ".jpeg")):  
            return os.path.join(ruta_carpeta, archivo)
    return None  # No encontró imágenes


ruta_gatos = "dataset/gatos"
ruta_perros = "dataset/perros"


archivo_gato = obtener_imagen_valida(ruta_gatos)
archivo_perro = obtener_imagen_valida(ruta_perros)

if archivo_gato and archivo_perro: 
    imagen_gato = Image.open(archivo_gato)
    imagen_perro = Image.open(archivo_perro)


    fig, axs = plt.subplots(1, 2, figsize=(8, 4))

    axs[0].imshow(imagen_gato)
    axs[0].axis("off")
    axs[0].set_title("Gato")

    axs[1].imshow(imagen_perro)
    axs[1].axis("off")
    axs[1].set_title("Perro")

    plt.show()
else:
    print("No se encontraron imágenes en las carpetas.")

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier


carpeta_base = "dataset"  


img_size = (100, 100)


imagenes = []
etiquetas = []


for categoria in ["gatos", "perros"]:
    carpeta = os.path.join(carpeta_base, categoria)
    etiqueta = 0 if categoria == "gatos" else 1
    
    for archivo in os.listdir(carpeta):
        ruta_img = os.path.join(carpeta, archivo)
        img = cv2.imread(ruta_img)  # Leer imagen
        if img is not None:
            img = cv2.resize(img, img_size) 
            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  
            imagenes.append(img.flatten())  
            etiquetas.append(etiqueta)


imagenes = np.array(imagenes)
etiquetas = np.array(etiquetas)


X_train, X_test, y_train, y_test = train_test_split(imagenes, etiquetas, test_size=0.2, random_state=42)

print("✅ Imágenes cargadas y divididas correctamente")

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\USER\Downloads\proyecto

# %%
# !pip install opencv-python

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier


carpeta_base = "dataset"  #

# Tamaño de las imágenes
img_size = (100, 100)


imagenes = []
etiquetas = []


for categoria in ["gatos", "perros"]:
    carpeta = os.path.join(carpeta_base, categoria)
    etiqueta = 0 if categoria == "gatos" else 1
    
    if not os.path.exists(carpeta):
        print(f"⚠️ La carpeta {categoria} no existe en {carpeta_base}.")
        continue
    
    for archivo in os.listdir(carpeta):
        if archivo.lower().endswith((".png", ".jpg", ".jpeg")):  # Filtrar solo imágenes
            ruta_img = os.path.join(carpeta, archivo)
            img = cv2.imread(ruta_img)  # Leer imagen
            if img is not None:
                img = cv2.resize(img, img_size)  # Redimensionar
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # Convertir a escala de grises
                imagenes.append(img.flatten())  # Convertir a vector 1D
                etiquetas.append(etiqueta)


imagenes = np.array(imagenes)
etiquetas = np.array(etiquetas)


X_train, X_test, y_train, y_test = train_test_split(imagenes, etiquetas, test_size=0.2, random_state=42)

print("✅ Imágenes cargadas y divididas correctamente")
# Out:
# ✅ Imágenes cargadas y divididas correctamente

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\user\downloads\mi_entorno\lib\site-packages (8.3.98)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ultralytics) (2.1.1)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ultralytics) (3.10.1)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ultralytics) (2.6.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ultralytics) (0.21.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in c:\users\user\downloads\mi_entorno\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\user\downloads\mi_entorno\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\downloads\mi_entorno\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\downloads\mi_entorno\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\downloads\mi_entorno\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\downloads\mi_entorno\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\downloads\mi_entorno\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\downloads\mi_entorno\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in c:\users\user\downloads\mi_entorno\lib\site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from torch>=1.8.0->ultralytics) (4.13.0)
# Requirement already satisfied: networkx in c:\users\user\downloads\mi_entorno\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\user\downloads\mi_entorno\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\user\downloads\mi_entorno\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: setuptools in c:\users\user\downloads\mi_entorno\lib\site-packages (from torch>=1.8.0->ultralytics) (78.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\user\downloads\mi_entorno\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in c:\users\user\downloads\mi_entorno\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\user\downloads\mi_entorno\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\downloads\mi_entorno\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import os


modelo = YOLO("yolov8n.pt")  


carpetas = {
    "dog": "dataset/perros/",
    "cat": "dataset/gatos/",
    "car": "dataset/carros/",
    "otros": "dataset/otros/" 
}

def detectar_animales(nombre_imagen, indice):
    ruta_imagen = None

    
    for carpeta in carpetas.values():
        posible_ruta = os.path.join(carpeta, nombre_imagen)
        if os.path.exists(posible_ruta):
            ruta_imagen = posible_ruta
            break

    if ruta_imagen is None:
        print(f"❌ No se encontró la imagen {indice} en ninguna carpeta.")
        return

    # Cargar imagen
    img = cv2.imread(ruta_imagen)
    if img is None:
        print(f"❌ No se pudo cargar la imagen {indice}. Verifica la ruta.")
        return

   
    resultados = modelo(ruta_imagen)

 
    detecto_perro = False
    detecto_gato = False
    detecto_carro = False

   
    for resultado in resultados:
        for box in resultado.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  
            clase = int(box.cls[0]) 
            confianza = box.conf[0].item()  

         
            nombre_clase = modelo.names[clase]

            # Definir color y marcar detecciones
            if nombre_clase == "dog":
                color = (0, 255, 0)  # Verde
                detecto_perro = True
            elif nombre_clase == "cat":
                color = (255, 0, 0)  # Azul
                detecto_gato = True
            elif nombre_clase == "car":
                color = (0, 0, 255)  # Rojo
                detecto_carro = True
            else:
                continue  # Si no es perro, gato o carro, ignorarlo

            cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)
            cv2.putText(img, f"{nombre_clase} ({confianza:.2f})", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

  
    if detecto_perro:
        print(f"✅ Se detectó un perro en la imagen {indice}.")
    if detecto_gato:
        print(f"✅ Se detectó un gato en la imagen {indice}.")
    if detecto_carro:
        print(f"✅ Se detectó un carro en la imagen {indice}.")
    if not (detecto_perro or detecto_gato or detecto_carro):
        print(f"❌ No se detectó ni un perro, ni un gato, ni un carro en la imagen {indice}.")

  
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()


detectar_animales("gatoproyecto.jpg", 1)
detectar_animales("perroproyecto2.jpg", 2)
detectar_animales("carroproyecto3.jpg", 3)
detectar_animales("ejemplo5.jpg", 4)
# Out:
# image 1/1 C:\Users\USER\Downloads\proyecto\dataset\gatos\gatoproyecto.jpg: 448x640 1 cat, 31.2ms
# Speed: 2.1ms preprocess, 31.2ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
# ✅ Se detectó un gato en la imagen 1.
# image 1/1 C:\Users\USER\Downloads\proyecto\dataset\perros\perroproyecto2.jpg: 384x640 1 dog, 29.3ms
# Speed: 1.2ms preprocess, 29.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Se detectó un perro en la imagen 2.
# image 1/1 C:\Users\USER\Downloads\proyecto\dataset\carros\carroproyecto3.jpg: 480x640 1 car, 31.9ms
# Speed: 1.5ms preprocess, 31.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Se detectó un carro en la imagen 3.
# image 1/1 C:\Users\USER\Downloads\proyecto\dataset\otros\ejemplo5.jpg: 448x640 1 car, 1 cat, 1 dog, 28.9ms
# Speed: 1.2ms preprocess, 28.9ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
# ✅ Se detectó un perro en la imagen 4.
# ✅ Se detectó un gato en la imagen 4.
# ✅ Se detectó un carro en la imagen 4.

# %%
import os
print(os.path.exists("haarcascade_frontalcatface_extended.xml"))
print(os.path.exists("haarcascade_frontalface_alt.xml"))
# Out:
# True
# True

# %%
ruta_imagenes = r'C:\Users\USER\Downloads\proyecto\imagenes'

if os.path.exists(ruta_imagenes):
    print("La carpeta de imágenes existe y está accesible")
else:
    print("La carpeta de imágenes no está accesible")
# Out:
# La carpeta de imágenes existe y está accesible

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.preprocessing import StandardScaler


carpeta = r"C:\Users\USER\Downloads\proyecto\imagenes"
nombre_imagen = "carroproyecto1.jpg"
ruta_imagen = os.path.join(carpeta, nombre_imagen)


def cargar_imagen(ruta):
    try:
        img = Image.open(ruta)
        img = img.resize((224, 224))  
        plt.imshow(img)
        plt.axis('off')
        plt.show()
    except Exception as e:
        print(f"Error al cargar la imagen: {e}")


def procesar_imagen(ruta):
    try:
        img = Image.open(ruta).convert('RGB')
        img = img.resize((224, 224))  
        img_array = np.array(img) / 255.0  # Normalización
        img_array = img_array.reshape(1, -1)  
        scaler = StandardScaler()
        img_array = scaler.fit_transform(img_array)  
        return img_array
    except Exception as e:
        print(f"Error al procesar la imagen: {e}")
        return None


if os.path.exists(ruta_imagen):  
    cargar_imagen(ruta_imagen)
    imagen_procesada = procesar_imagen(ruta_imagen)
    if imagen_procesada is not None:
        print("Imagen procesada correctamente:", imagen_procesada.shape)
else:
    print("No se encontró la imagen en la ruta especificada.")
# Out:
# Imagen procesada correctamente: (1, 150528)

# %%
for etiqueta in os.listdir(ruta_imagenes):
    carpeta = os.path.join(ruta_imagenes, etiqueta)
    if os.path.isdir(carpeta):
        print(f"Carpeta detectada: {etiqueta}, contiene {len(os.listdir(carpeta))} archivos")
# Out:
# Carpeta detectada: .ipynb_checkpoints, contiene 0 archivos
# Carpeta detectada: carros, contiene 5 archivos
# Carpeta detectada: gatos, contiene 5 archivos
# Carpeta detectada: imagenes, contiene 7 archivos
# Carpeta detectada: Otros, contiene 4 archivos
# Carpeta detectada: perros, contiene 5 archivos

# %%
if len(np.unique(y)) < 2:
    raise ValueError("Error: Se necesita al menos dos clases para entrenar el modelo.")

# %%
# !apt-get update && apt-get install -y libgl1-mesa-glx
# Out:
# "apt-get" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
